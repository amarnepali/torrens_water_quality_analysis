# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torrens-lake-metrological-data/Metadata_TorrensWaterData.pdf
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Aug_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Dec_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_May_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Apr_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Aug_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Dec_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jul_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Sep_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Nov_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Dec_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jul_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Oct_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Dec_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Oct_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jun_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jul_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Mar_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jun_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_May_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jan_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jan_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Feb_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Feb_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jun_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jul_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Oct_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/Historic_Torrens_Weir.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Sep_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Oct_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Oct_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jun_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jan_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Oct_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Aug_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Mar_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Nov_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jun_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Sep_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_May_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Aug_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_May_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jan_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jul_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Feb_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Feb_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Apr_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jun_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Feb_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Apr_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Dec_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_May_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jan_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Nov_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/TORREN2796133400_May_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_May_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Dec_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Aug_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Feb_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Mar_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Mar_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_May_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Sep_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Apr_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jan_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Apr_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Aug_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Mar_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Sep_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Mar_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/Historic_Adelaide_Zoo.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Dec_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Dec_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Nov_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Apr_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jul_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Aug_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/TORREN2811133400_May_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Nov_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Oct_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Nov_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Mar_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jun_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Feb_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Jul_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Feb_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Nov_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Oct_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Nov_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jul_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_May_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Sep_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jan_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Sep_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Sep_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jun_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jan_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Aug_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Oct_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/TORREN2817134100_May_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/Historic_Adelaide_Uni.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Nov_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Jan_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2015.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_Dec_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Feb_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041055_Adelaide_Uni_May_2017.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2018.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Mar_2016.csv
# /kaggle/input/torrens-lake-metrological-data/torrens/A5041056_Torrens_Weir_Mar_2017.csv

# %%
import pandas as pd
read_csv = pd.read_csv('/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2016.csv')

# %%
read_csv.head(5)
# Out:
#                                                                                                                                                                    Friendly Name:A5041054 - Adelaide Zoo
# TIMESTAMP           batt_volts modem_resets WTemp E_Cond O2_percent O2_mg TAC_temp(1) TAC_temp(2) TAC_temp(3) TAC_temp(4) TAC_temp(5) TAC_temp(6) TAC_errorsensors                               Sp_Cond
# TS                  V          d            C     uS/cm  %          mg/L  C           C           C           C           C           C           d                                                uS/cm
# NaN                 NaN        NaN          NaN   NaN    NaN        NaN   NaN         NaN         NaN         NaN         NaN         NaN         NaN                                                NaN
# 2016-04-01 00:00:00 12.95      107.0        19.29 1026.0 13.7       1.26  18.92       18.98       18.85       18.98       18.67       18.54       0.0                                             1151.0
# 2016-04-01 00:15:00 12.95      107.0        19.25 1030.0 13.7       1.26  18.85       18.98       18.79       18.92       18.67       18.54       0.0                                             1157.0

# %%
# lets combine all files into single piece files name starts with A5041054**_.csv for adelaide_zoo
import glob
import numpy as np
import os

file_path = "/kaggle/input/torrens-lake-metrological-data/torrens/"

combined_files = glob.glob(os.path.join(file_path,"A5041054**.csv"))

# %%
combined_files
# Out:
# ['/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Dec_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Nov_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_May_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jan_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Oct_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Oct_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Nov_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jan_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Feb_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Feb_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_May_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_May_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Feb_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Mar_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Mar_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Dec_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Dec_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Nov_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Sep_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jun_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jan_2017.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Oct_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2016.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Jul_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Aug_2015.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Apr_2018.csv',
#  '/kaggle/input/torrens-lake-metrological-data/torrens/A5041054_Adelaide_Zoo_Mar_2016.csv']

# %%
# Read and combine all CSVs into one DataFrame
rename_col = {
    'TS': 'TIMESTAMP',
    'V': 'batt_volts',
    'd': 'modem_resets',
    'C': 'WaterTemp',
    'uS/cm': 'Electrical_Conductivity',
    '%': 'O2_percent',
    'mg/L': 'O2_mg',
    'C.1': 'TAC_temp(0.1 m)',
    'C.2': 'TAC_temp(0.2 m)',
    'C.3': 'TAC_temp(0.3 m)',
    'C.4': 'TAC_temp(0.4 m)',
    'C.5': 'TAC_temp(0.5 m)',
    'C.6': 'TAC_temp(0.6 m)',
    'd.1': 'TAC_errorsensors',
    'uS/cm.1': 'Sp_Cond'
}


# pd.concat([pd.read_csv(file, skiprow=2) for file in combined_files], ignore_index = True)

combined_df_Adl_zoo = pd.concat([
    pd.read_csv(file, skiprows=2).assign(
        SITE="Adelaide Zoo"
    ).rename(columns=rename_col)
    for file in combined_files
], ignore_index=True)

# View first few rows
combined_df_Adl_zoo.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#              TIMESTAMP  batt_volts  modem_resets  WaterTemp  \
# 0                  NaN         NaN           NaN        NaN
# 1  2017-06-01 00:00:00       12.93        7999.0      13.02
# 2  2017-06-01 00:15:00       12.95        7999.0      13.02
# 3  2017-06-01 00:30:00       12.94        7999.0      13.01
# 4  2017-06-01 00:45:00       12.93        7999.0      13.00
#
#    Electrical_Conductivity  O2_percent  O2_mg  TAC_temp(0.1 m)  \
# 0                      NaN         NaN    NaN              NaN
# 1                    313.0         3.0   0.31            12.31
# 2                    314.0         3.0   0.31            12.25
# 3                    315.0         2.9   0.31            12.37
# 4                    316.0         2.9   0.31            12.18
#
#    TAC_temp(0.2 m)  TAC_temp(0.3 m)  TAC_temp(0.4 m)  TAC_temp(0.5 m)  \
# 0              NaN              NaN              NaN              NaN
# 1            12.75            12.75            12.87            12.75
# 2            12.75            12.75            12.81            12.75
# 3            12.75            12.75            12.81            12.75
# 4            12.75            12.68            12.81            12.75
#
#    TAC_temp(0.6 m)  TAC_errorsensors  Sp_Cond          SITE
# 0              NaN               NaN      NaN  Adelaide Zoo
# 1            12.93               0.0    406.0  Adelaide Zoo
# 2            13.00               0.0    407.0  Adelaide Zoo
# 3            12.93               0.0    409.0  Adelaide Zoo
# 4            12.87               0.0    410.0  Adelaide Zoo

# %%
len(combined_df_Adl_zoo)
# Out:
# 112698

# %%
# sort the combined_df_Adl_zoo data based on timestamp

# makeing sure df timestamp is in pd datetime format

combined_df_Adl_zoo['TIMESTAMP'] = pd.to_datetime(combined_df_Adl_zoo["TIMESTAMP"], errors="coerce")

# sort by timestamp
combined_df_Adl_zoo = combined_df_Adl_zoo.sort_values("TIMESTAMP").reset_index(drop =True)

# %%
combined_df_Adl_zoo.tail(50)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                  TIMESTAMP  batt_volts  modem_resets  WaterTemp  \
# 112648 2018-09-07 10:15:00       12.66        7999.0      13.61
# 112649 2018-09-07 10:30:00       12.66        7999.0      13.59
# 112650 2018-09-07 10:45:00       12.66        7999.0      13.57
# 112651 2018-09-07 11:00:00       12.66        7999.0      13.59
# 112652 2018-09-07 11:15:00       12.64        7999.0      13.58
# 112653 2018-09-07 11:30:00       12.65        7999.0      13.61
# 112654 2018-09-07 11:45:00       12.65        7999.0      13.64
# 112655 2018-09-07 12:00:00       12.64        7999.0      13.68
# 112656 2018-09-07 12:15:00       12.64        7999.0      13.75
# 112657 2018-09-07 12:30:00       12.64        7999.0      13.85
# 112658                 NaT         NaN           NaN        NaN
# 112659                 NaT         NaN           NaN        NaN
# 112660                 NaT         NaN           NaN        NaN
# 112661                 NaT         NaN           NaN        NaN
# 112662                 NaT         NaN           NaN        NaN
# 112663                 NaT         NaN           NaN        NaN
# 112664                 NaT         NaN           NaN        NaN
# 112665                 NaT         NaN           NaN        NaN
# 112666                 NaT         NaN           NaN        NaN
# 112667                 NaT         NaN           NaN        NaN
# 112668                 NaT         NaN           NaN        NaN
# 112669                 NaT         NaN           NaN        NaN
# 112670                 NaT         NaN           NaN        NaN
# 112671                 NaT         NaN           NaN        NaN
# 112672                 NaT         NaN           NaN        NaN
# 112673                 NaT         NaN           NaN        NaN
# 112674                 NaT         NaN           NaN        NaN
# 112675                 NaT         NaN           NaN        NaN
# 112676                 NaT         NaN           NaN        NaN
# 112677                 NaT         NaN           NaN        NaN
# 112678                 NaT         NaN           NaN        NaN
# 112679                 NaT         NaN           NaN        NaN
# 112680                 NaT         NaN           NaN        NaN
# 112681                 NaT         NaN           NaN        NaN
# 112682                 NaT         NaN           NaN        NaN
# 112683                 NaT         NaN           NaN        NaN
# 112684                 NaT         NaN           NaN        NaN
# 112685                 NaT         NaN           NaN        NaN
# 112686                 NaT         NaN           NaN        NaN
# 112687                 NaT         NaN           NaN        NaN
# 112688                 NaT         NaN           NaN        NaN
# 112689                 NaT         NaN           NaN        NaN
# 112690                 NaT         NaN           NaN        NaN
# 112691                 NaT         NaN           NaN        NaN
# 112692                 NaT         NaN           NaN        NaN
# 112693                 NaT         NaN           NaN        NaN
# 112694                 NaT         NaN           NaN        NaN
# 112695                 NaT         NaN           NaN        NaN
# 112696                 NaT         NaN           NaN        NaN
# 112697                 NaT         NaN           NaN        NaN
#
#         Electrical_Conductivity  O2_percent  O2_mg  TAC_temp(0.1 m)  \
# 112648                    855.0         4.1   0.43            14.74
# 112649                    855.0         4.2   0.43            14.74
# 112650                    855.0         4.3   0.45            14.87
# 112651                    856.0         4.3   0.44            14.62
# 112652                    857.0         4.5   0.46            14.87
# 112653                    857.0         4.5   0.47            14.99
# 112654                    859.0         4.3   0.44            15.30
# 112655                    860.0         4.3   0.44            15.49
# 112656                    861.0         4.2   0.44            15.55
# 112657                    864.0         4.3   0.45            15.74
# 112658                      NaN         NaN    NaN              NaN
# 112659                      NaN         NaN    NaN              NaN
# 112660                      NaN         NaN    NaN              NaN
# 112661                      NaN         NaN    NaN              NaN
# 112662                      NaN         NaN    NaN              NaN
# 112663                      NaN         NaN    NaN              NaN
# 112664                      NaN         NaN    NaN              NaN
# 112665                      NaN         NaN    NaN              NaN
# 112666                      NaN         NaN    NaN              NaN
# 112667                      NaN         NaN    NaN              NaN
# 112668                      NaN         NaN    NaN              NaN
# 112669                      NaN         NaN    NaN              NaN
# 112670                      NaN         NaN    NaN              NaN
# 112671                      NaN         NaN    NaN              NaN
# 112672                      NaN         NaN    NaN              NaN
# 112673                      NaN         NaN    NaN              NaN
# 112674                      NaN         NaN    NaN              NaN
# 112675                      NaN         NaN    NaN              NaN
# 112676                      NaN         NaN    NaN              NaN
# 112677                      NaN         NaN    NaN              NaN
# 112678                      NaN         NaN    NaN              NaN
# 112679                      NaN         NaN    NaN              NaN
# 112680                      NaN         NaN    NaN              NaN
# 112681                      NaN         NaN    NaN              NaN
# 112682                      NaN         NaN    NaN              NaN
# 112683                      NaN         NaN    NaN              NaN
# 112684                      NaN         NaN    NaN              NaN
# 112685                      NaN         NaN    NaN              NaN
# 112686                      NaN         NaN    NaN              NaN
# 112687                      NaN         NaN    NaN              NaN
# 112688                      NaN         NaN    NaN              NaN
# 112689                      NaN         NaN    NaN              NaN
# 112690                      NaN         NaN    NaN              NaN
# 112691                      NaN         NaN    NaN              NaN
# 112692                      NaN         NaN    NaN              NaN
# 112693                      NaN         NaN    NaN              NaN
# 112694                      NaN         NaN    NaN              NaN
# 112695                      NaN         NaN    NaN              NaN
# 112696                      NaN         NaN    NaN              NaN
# 112697                      NaN         NaN    NaN              NaN
#
#         TAC_temp(0.2 m)  TAC_temp(0.3 m)  TAC_temp(0.4 m)  TAC_temp(0.5 m)  \
# 112648            13.50            13.25            13.18            13.37
# 112649            13.43            13.18            13.25            13.43
# 112650            13.50            13.31            13.31            13.43
# 112651            13.50            13.25            13.18            13.37
# 112652            13.68            13.37            13.31            13.37
# 112653            13.81            13.37            13.37            13.43
# 112654            13.87            13.37            13.37            13.43
# 112655            14.06            13.50            13.43            13.49
# 112656            14.31            13.56            13.43            13.49
# 112657            14.43            13.68            13.50            13.56
# 112658              NaN              NaN              NaN              NaN
# 112659              NaN              NaN              NaN              NaN
# 112660              NaN              NaN              NaN              NaN
# 112661              NaN              NaN              NaN              NaN
# 112662              NaN              NaN              NaN              NaN
# 112663              NaN              NaN              NaN              NaN
# 112664              NaN              NaN              NaN              NaN
# 112665              NaN              NaN              NaN              NaN
# 112666              NaN              NaN              NaN              NaN
# 112667              NaN              NaN              NaN              NaN
# 112668              NaN              NaN              NaN              NaN
# 112669              NaN              NaN              NaN              NaN
# 112670              NaN              NaN              NaN              NaN
# 112671              NaN              NaN              NaN              NaN
# 112672              NaN              NaN              NaN              NaN
# 112673              NaN              NaN              NaN              NaN
# 112674              NaN              NaN              NaN              NaN
# 112675              NaN              NaN              NaN              NaN
# 112676              NaN              NaN              NaN              NaN
# 112677              NaN              NaN              NaN              NaN
# 112678              NaN              NaN              NaN              NaN
# 112679              NaN              NaN              NaN              NaN
# 112680              NaN              NaN              NaN              NaN
# 112681              NaN              NaN              NaN              NaN
# 112682              NaN              NaN              NaN              NaN
# 112683              NaN              NaN              NaN              NaN
# 112684              NaN              NaN              NaN              NaN
# 112685              NaN              NaN              NaN              NaN
# 112686              NaN              NaN              NaN              NaN
# 112687              NaN              NaN              NaN              NaN
# 112688              NaN              NaN              NaN              NaN
# 112689              NaN              NaN              NaN              NaN
# 112690              NaN              NaN              NaN              NaN
# 112691              NaN              NaN              NaN              NaN
# 112692              NaN              NaN              NaN              NaN
# 112693              NaN              NaN              NaN              NaN
# 112694              NaN              NaN              NaN              NaN
# 112695              NaN              NaN              NaN              NaN
# 112696              NaN              NaN              NaN              NaN
# 112697              NaN              NaN              NaN              NaN
#
#         TAC_temp(0.6 m)  TAC_errorsensors  Sp_Cond          SITE
# 112648            13.93               0.0   1092.0  Adelaide Zoo
# 112649            13.93               0.0   1093.0  Adelaide Zoo
# 112650            13.99               0.0   1094.0  Adelaide Zoo
# 112651            13.99               0.0   1095.0  Adelaide Zoo
# 112652            13.93               0.0   1096.0  Adelaide Zoo
# 112653            13.93               0.0   1096.0  Adelaide Zoo
# 112654            13.99               0.0   1097.0  Adelaide Zoo
# 112655            13.99               0.0   1097.0  Adelaide Zoo
# 112656            13.99               0.0   1097.0  Adelaide Zoo
# 112657            13.93               0.0   1098.0  Adelaide Zoo
# 112658              NaN               NaN      NaN  Adelaide Zoo
# 112659              NaN               NaN      NaN  Adelaide Zoo
# 112660              NaN               NaN      NaN  Adelaide Zoo
# 112661              NaN               NaN      NaN  Adelaide Zoo
# 112662              NaN               NaN      NaN  Adelaide Zoo
# 112663              NaN               NaN      NaN  Adelaide Zoo
# 112664              NaN               NaN      NaN  Adelaide Zoo
# 112665              NaN               NaN      NaN  Adelaide Zoo
# 112666              NaN               NaN      NaN  Adelaide Zoo
# 112667              NaN               NaN      NaN  Adelaide Zoo
# 112668              NaN               NaN      NaN  Adelaide Zoo
# 112669              NaN               NaN      NaN  Adelaide Zoo
# 112670              NaN               NaN      NaN  Adelaide Zoo
# 112671              NaN               NaN      NaN  Adelaide Zoo
# 112672              NaN               NaN      NaN  Adelaide Zoo
# 112673              NaN               NaN      NaN  Adelaide Zoo
# 112674              NaN               NaN      NaN  Adelaide Zoo
# 112675              NaN               NaN      NaN  Adelaide Zoo
# 112676              NaN               NaN      NaN  Adelaide Zoo
# 112677              NaN               NaN      NaN  Adelaide Zoo
# 112678              NaN               NaN      NaN  Adelaide Zoo
# 112679              NaN               NaN      NaN  Adelaide Zoo
# 112680              NaN               NaN      NaN  Adelaide Zoo
# 112681              NaN               NaN      NaN  Adelaide Zoo
# 112682              NaN               NaN      NaN  Adelaide Zoo
# 112683              NaN               NaN      NaN  Adelaide Zoo
# 112684              NaN               NaN      NaN  Adelaide Zoo
# 112685              NaN               NaN      NaN  Adelaide Zoo
# 112686              NaN               NaN      NaN  Adelaide Zoo
# 112687              NaN               NaN      NaN  Adelaide Zoo
# 112688              NaN               NaN      NaN  Adelaide Zoo
# 112689              NaN               NaN      NaN  Adelaide Zoo
# 112690              NaN               NaN      NaN  Adelaide Zoo
# 112691              NaN               NaN      NaN  Adelaide Zoo
# 112692              NaN               NaN      NaN  Adelaide Zoo
# 112693              NaN               NaN      NaN  Adelaide Zoo
# 112694              NaN               NaN      NaN  Adelaide Zoo
# 112695              NaN               NaN      NaN  Adelaide Zoo
# 112696              NaN               NaN      NaN  Adelaide Zoo
# 112697              NaN               NaN      NaN  Adelaide Zoo

# %%
# Cleaning process

# check for null values
combined_df_Adl_zoo.isnull().sum()
# Out:
# TIMESTAMP                    40
# batt_volts                   40
# modem_resets                 40
# WaterTemp                    50
# Electrical_Conductivity      40
# O2_percent                   40
# O2_mg                        40
# TAC_temp(0.1 m)              40
# TAC_temp(0.2 m)              40
# TAC_temp(0.3 m)              40
# TAC_temp(0.4 m)              40
# TAC_temp(0.5 m)              40
# TAC_temp(0.6 m)              40
# TAC_errorsensors           4632
# Sp_Cond                      40
# SITE                          0
# dtype: int64

# %%
Cleaned_df_Adl_Zoo = combined_df_Adl_zoo.dropna(subset=['TIMESTAMP', 'WaterTemp'])

# %%
Cleaned_df_Adl_Zoo.isnull().sum()
# Out:
# TIMESTAMP                     0
# batt_volts                    0
# modem_resets                  0
# WaterTemp                     0
# Electrical_Conductivity       0
# O2_percent                    0
# O2_mg                         0
# TAC_temp(0.1 m)               0
# TAC_temp(0.2 m)               0
# TAC_temp(0.3 m)               0
# TAC_temp(0.4 m)               0
# TAC_temp(0.5 m)               0
# TAC_temp(0.6 m)               0
# TAC_errorsensors           4592
# Sp_Cond                       0
# SITE                          0
# dtype: int64

# %%
# lets fill the null values of TAC_errorsensors with mean values

mean_val = Cleaned_df_Adl_Zoo['TAC_errorsensors'].mean()
# Fill null values with the mean
Cleaned_df_Adl_Zoo.loc[:,"TAC_errorsensors"] = Cleaned_df_Adl_Zoo["TAC_errorsensors"].fillna(mean_val)

# %%
Cleaned_df_Adl_Zoo
# Out:
#                  TIMESTAMP  batt_volts  modem_resets  WaterTemp  \
# 0      2015-06-01 00:00:00       13.00          15.0      14.83
# 1      2015-06-01 00:15:00       13.00          15.0      14.82
# 2      2015-06-01 00:30:00       13.00          15.0      14.81
# 3      2015-06-01 00:45:00       12.97          15.0      14.80
# 4      2015-06-01 01:00:00       12.99          15.0      14.78
# ...                    ...         ...           ...        ...
# 112653 2018-09-07 11:30:00       12.65        7999.0      13.61
# 112654 2018-09-07 11:45:00       12.65        7999.0      13.64
# 112655 2018-09-07 12:00:00       12.64        7999.0      13.68
# 112656 2018-09-07 12:15:00       12.64        7999.0      13.75
# 112657 2018-09-07 12:30:00       12.64        7999.0      13.85
#
#         Electrical_Conductivity  O2_percent  O2_mg  TAC_temp(0.1 m)  \
# 0                         536.0         2.9   0.29            14.55
# 1                         535.0         2.4   0.25            14.49
# 2                         533.0         2.3   0.23            14.43
# 3                         532.0         2.2   0.22            14.43
# 4                         532.0         1.8   0.18            14.43
# ...                         ...         ...    ...              ...
# 112653                    857.0         4.5   0.47            14.99
# 112654                    859.0         4.3   0.44            15.30
# 112655                    860.0         4.3   0.44            15.49
# 112656                    861.0         4.2   0.44            15.55
# 112657                    864.0         4.3   0.45            15.74
#
#         TAC_temp(0.2 m)  TAC_temp(0.3 m)  TAC_temp(0.4 m)  TAC_temp(0.5 m)  \
# 0                 14.68            14.56            14.68            14.55
# 1                 14.68            14.56            14.68            14.55
# 2                 14.68            14.49            14.62            14.55
# 3                 14.62            14.49            14.62            14.49
# 4                 14.62            14.49            14.62            14.49
# ...                 ...              ...              ...              ...
# 112653            13.81            13.37            13.37            13.43
# 112654            13.87            13.37            13.37            13.43
# 112655            14.06            13.50            13.43            13.49
# 112656            14.31            13.56            13.43            13.49
# 112657            14.43            13.68            13.50            13.56
#
#         TAC_temp(0.6 m)  TAC_errorsensors  Sp_Cond          SITE
# 0                 14.68               0.0    665.0  Adelaide Zoo
# 1                 14.74               0.0    664.0  Adelaide Zoo
# 2                 14.68               0.0    662.0  Adelaide Zoo
# 3                 14.68               0.0    661.0  Adelaide Zoo
# 4                 14.68               0.0    660.0  Adelaide Zoo
# ...                 ...               ...      ...           ...
# 112653            13.93               0.0   1096.0  Adelaide Zoo
# 112654            13.99               0.0   1097.0  Adelaide Zoo
# 112655            13.99               0.0   1097.0  Adelaide Zoo
# 112656            13.99               0.0   1097.0  Adelaide Zoo
# 112657            13.93               0.0   1098.0  Adelaide Zoo
#
# [112648 rows x 16 columns]

# %%
import matplotlib.pyplot as plt

# Plot WTemp (or any other parameter)
plt.figure(figsize=(14, 5))
plt.plot(Cleaned_df_Adl_Zoo["TIMESTAMP"], Cleaned_df_Adl_Zoo["WaterTemp"], label="Water Temperature (°C)")
plt.xlabel("Timestamp")
plt.ylabel("Water Temperature (°C)")
plt.title("Water Temperature Over Time - Adelaide Zoo")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot WTemp (or any other parameter)
plt.figure(figsize=(14, 5))
plt.plot(Cleaned_df_Adl_Zoo["TIMESTAMP"], Cleaned_df_Adl_Zoo["O2_mg"], label="oxygen mg/L")
plt.xlabel("Timestamp")
plt.ylabel("O2 mg/L")
plt.title("oxygen level over Time - Adelaide Zoo")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# lets plot multi-variable time series plot

Cleaned_df_Adl_Zoo.set_index("TIMESTAMP")[["WaterTemp", "O2_percent","O2_mg", "Sp_Cond", "Electrical_Conductivity"]].plot(figsize=(14, 6), title="Water Quality Parameters - Adelaide Zoo")
# Out:
# <Axes: title={'center': 'Water Quality Parameters - Adelaide Zoo'}, xlabel='TIMESTAMP'>

# %%
# lets find the correlation between the variables doing pearson correlation test

from scipy.stats import pearsonr
from itertools import combinations
import pandas as pd

#  columns of interest
columns = ["WaterTemp", "Electrical_Conductivity", "Sp_Cond", "O2_percent", "O2_mg"]

# Run pairwise correlation tests
results = []

for var1, var2 in combinations(columns,2):
    corr, p = pearsonr(Cleaned_df_Adl_Zoo[var1], Cleaned_df_Adl_Zoo[var2])
    results.append({
        "Variable 1": var1,
        "Variable 2": var2,
        "Pearson r": round(corr, 3),
        "P-value": round(p, 5),
        "Significant?": "✅ Yes" if p < 0.05 else "❌ No"
    })

# Convert to DataFrame
results_df = pd.DataFrame(results)
results_df
# Out:
#                 Variable 1               Variable 2  Pearson r  P-value  \
# 0                WaterTemp  Electrical_Conductivity      0.602      0.0
# 1                WaterTemp                  Sp_Cond      0.426      0.0
# 2                WaterTemp               O2_percent      0.069      0.0
# 3                WaterTemp                    O2_mg     -0.050      0.0
# 4  Electrical_Conductivity                  Sp_Cond      0.974      0.0
# 5  Electrical_Conductivity               O2_percent     -0.152      0.0
# 6  Electrical_Conductivity                    O2_mg     -0.227      0.0
# 7                  Sp_Cond               O2_percent     -0.212      0.0
# 8                  Sp_Cond                    O2_mg     -0.268      0.0
# 9               O2_percent                    O2_mg      0.986      0.0
#
#   Significant?
# 0        ✅ Yes
# 1        ✅ Yes
# 2        ✅ Yes
# 3        ✅ Yes
# 4        ✅ Yes
# 5        ✅ Yes
# 6        ✅ Yes
# 7        ✅ Yes
# 8        ✅ Yes
# 9        ✅ Yes

# %%
# lets do plot a heatmap and pairwise scatter plot

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Subset the 4 variables
cols = ["WaterTemp", "Electrical_Conductivity", "Sp_Cond", "O2_percent", "O2_mg"]
df_plot = Cleaned_df_Adl_Zoo[cols]

#  Correlation Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_plot.corr(), annot=True, cmap="coolwarm", fmt=".2f", square=True)
plt.title("Correlation Heatmap: Water Quality Parameters")
plt.tight_layout()
plt.show()

# %%
#  Scatter Plot Matrix with Regression Lines
sns.pairplot(df_plot, kind="reg", plot_kws={"line_kws":{'color':'red'}, "scatter_kws": {"alpha": 0.5}})
plt.suptitle("Pairwise Relationships with Regression Lines", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_plot["TIMESTAMP"] = pd.to_datetime(Cleaned_df_Adl_Zoo["TIMESTAMP"])
df_plot.set_index("TIMESTAMP")[["WaterTemp", "Electrical_Conductivity", "Sp_Cond", "O2_percent", "O2_mg"]].plot(figsize=(15,6))
# Out:
# <ipython-input-23-82eff7bb73b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot["TIMESTAMP"] = pd.to_datetime(Cleaned_df_Adl_Zoo["TIMESTAMP"])
# <Axes: xlabel='TIMESTAMP'>

# %%
# lets do normalize the values of variables using min-max noramlization

import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean the columns
cols = ["WaterTemp", "Electrical_Conductivity", "Sp_Cond", "O2_percent","O2_mg", "TIMESTAMP"]
df_norm = Cleaned_df_Adl_Zoo[cols]

# Step 2: Normalize (Min-Max scaling)
for col in cols[:-1]:  # exclude TIMESTAMP
    min_val = df_norm[col].min()
    max_val = df_norm[col].max()
    df_norm[col] = (df_norm[col] - min_val) / (max_val - min_val)

# Step 3: Convert TIMESTAMP to datetime and set as index
df_norm["TIMESTAMP"] = pd.to_datetime(df_norm["TIMESTAMP"])
df_norm.set_index("TIMESTAMP", inplace=True)

# Step 4: Plot
plt.figure(figsize=(15, 6))
df_norm.plot(ax=plt.gca(), linewidth=1.2)
plt.title("Normalized Time Series of Water Quality Parameters - Adelaide Zoo")
plt.xlabel("Time")
plt.ylabel("Normalized Value (0-1)")
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-29-3717d6c18e64>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_norm[col] = (df_norm[col] - min_val) / (max_val - min_val)
# <ipython-input-29-3717d6c18e64>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_norm["TIMESTAMP"] = pd.to_datetime(df_norm["TIMESTAMP"])

# %%
#  lets resample the normalized original data with collection gap of 15 min into daily

# Resample to daily frequency (mean)
daily_avg = df_norm.resample("D").mean()

plt.figure(figsize=(15, 6))
daily_avg.plot(ax=plt.gca(), linewidth=1.5)
plt.title("Normalized Daily Averages of Water Quality Parameters - Adelaide Zoo")
plt.xlabel("Date")
plt.ylabel("Normalized Value (0–1)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
# Apply 7-day (7*24*4 = 672 interval) rolling average
rolling_avg = df_norm.rolling(window=672, min_periods=1).mean()

# Step 4: Plot
plt.figure(figsize=(15, 6))
rolling_avg.plot(ax=plt.gca(), linewidth=1.5)
plt.title("7-Day Rolling Average (Normalized) - Water Quality at Adelaide Zoo")
plt.xlabel("Time")
plt.ylabel("Smoothed Normalized Value")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
# Resample to Monthly frequency (mean)
Monthly_avg = df_norm.resample("M").mean()

plt.figure(figsize=(15, 6))
Monthly_avg.plot(ax=plt.gca(), linewidth=1.5)
plt.title("Normalized Monthly Averages of Water Quality Parameters - Adelaide Zoo")
plt.xlabel("Date")
plt.ylabel("Normalized Value (0–1)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-360303ad9430>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   Monthly_avg = df_norm.resample("M").mean()

# %% [markdown]
# This montly frequency plot shows the clear view of percentange of oxygen in water is getting droped time, while others factors such as conductivity and temperature are fluctuating with season. And this decline in oxygen level in water is unsuitable for fish and other aquatic life (according to Department of Climate Change, Energy, the Environment and Water, Australia). According to "Fondriest Environmenta" Bottom  feeders, crabs, oysters and worms need minimal amounts of oxygen (1-6 mg/L), while shallow water fish need higher levels (4-15 mg/L)⁵.

# %%
# lets find some insights on oxygen level on month basis
columns = ["O2_mg", "TIMESTAMP"]
Oxygen_with_time = Cleaned_df_Adl_Zoo[columns]

Oxygen_with_time.set_index("TIMESTAMP", inplace=True)

Oxygen_per_month = Oxygen_with_time.resample("M").mean()
Oxygen_per_month.head()

plt.figure(figsize=(15, 6))
Oxygen_per_month.plot(ax=plt.gca(), linewidth=1.5)
plt.title("Normalized Monthly Averages of Water Quality Parameters - Adelaide Zoo")
plt.xlabel("Date")
plt.ylabel("Normalized Value (0–1)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-45-af44a48eaac9>:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   Oxygen_per_month = Oxygen_with_time.resample("M").mean()

# %%
len(Oxygen_per_month)
# Out:
# 40

# %% [markdown]
# The trend clearly shows after 2017, level of oxygen mg/L had started drop to unsuitable for marine life range, and could not get recover and keep dropping. Finding the reason behind this damage and solutions to bring the lake into life is necessary.
